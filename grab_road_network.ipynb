# %% [markdown]
# <a href="https://colab.research.google.com/github/ShiyanZh/Road-network/blob/main/grab_road_network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install osmnx

# %%
import osmnx as ox

# %%
import matplotlib.pyplot as plt

# %%
# Specify the name that is used to seach for the data
place_name = "Oakland, Alameda County, California, United States"
# Fetch OSM street network from the location
graph = ox.graph_from_place(place_name)
type(graph)
# Out:
# networkx.classes.multidigraph.MultiDiGraph

# %%
# Plot the streets
fig, ax = ox.plot_graph(graph)
